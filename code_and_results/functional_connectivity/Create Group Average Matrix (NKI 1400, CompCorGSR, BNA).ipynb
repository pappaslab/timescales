# %% [markdown]
# # Functional Connectivity - Create Group Average Matrix (NKI 1400, CompCorGSR, BNA)

# %%
from glob import glob
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Set up notebook options and plotting functions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
sns.set_context('notebook')

# %%
np.set_printoptions(suppress=True)

# %% [markdown]
# Load individual FC matrices.

# %%
subject_list = np.genfromtxt('/home/despoB/dlurie/Projects/timescale_hierarchy/data/meta/subject_lists/NKI-healthy_young.txt', dtype="U")

# %%
corrmat_CompCorGSR_fpt = '/home/despoB/nki_rs/data/derivatives/custom/sub-{0}/func/sub-{0}_ses-*_task-rest_acq-1400_bold_space-T1w_atlas-BNA_variant-CompCorGSR_corrmat.tsv'

# %%
corrmat_store = []
for sub_id in subject_list:
    data = np.loadtxt(glob(corrmat_CompCorGSR_fpt.format(sub_id))[0])
    np.fill_diagonal(data, 0)
    corrmat_store.append(data)
corrmat_store = np.array(corrmat_store)

# %%
corrmat_store.shape
# Out:
# (93, 246, 246)

# %% [markdown]
# Create a group average network.

# %%
zmat_store = []
for mat in corrmat_store:
    zmat_store.append(np.arctanh(mat)) # Fisher's transformation
zmat_store = np.array(zmat_store)
zmat_mean = np.mean(zmat_store, axis=0)

# %% [markdown]
# Plot the distribution of edge weights and the connectivity matrix.

# %%
f, axes = plt.subplots(1,2, figsize=(12,5))
sns.heatmap(zmat_mean, yticklabels=False, xticklabels=False, ax=axes[1], cmap='RdBu_r', center=0)
sns.histplot(zmat_mean.flatten(), ax=axes[0])
plt.tight_layout()

# %%
np.savetxt('/home/despoB/dlurie/Projects/timescale_hierarchy/results/functional_connectivity/NKI-1400_CompCorGSR_BNA_zmat_mean.csv',
          zmat_mean)

# %% [markdown]
# Create a matrix which includes only positive edges.

# %%
zmat_mean_po = zmat_mean.copy()

# %%
zmat_mean_po[zmat_mean_po < 0] = 0

# %%
np.savetxt('/home/despoB/dlurie/Projects/timescale_hierarchy/results/functional_connectivity/NKI-1400_CompCorGSR_BNA_zmat_mean_po.csv',
          zmat_mean_po)

# %% [markdown]
# Plot the distribution of edge weights and the connectivity matrix.

# %%
f, axes = plt.subplots(1,2, figsize=(12,5))
sns.heatmap(zmat_mean_po, yticklabels=False, xticklabels=False, ax=axes[1])
sns.histplot(zmat_mean_po.flatten()[zmat_mean_po.flatten() > 0], ax=axes[0])
plt.tight_layout()
